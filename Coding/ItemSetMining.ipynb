# %% [markdown]
# **Let's look at a Market Basket Analysis Example**

# %% [markdown]
# **we are using data collected from a SuperMarket, where each row indicates all the items purchased in a particular transaction.**

# %% [markdown]
# **The manager of a retail store is trying to find out an association rule between items, to figure out which items are more often bought together so that he can keep the items together in order to increase sales.**

# %%
# !pip install Apyori
# Out:
# Requirement already satisfied: Apyori in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (1.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#pip install kagglehub
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("parisanahmadi/market-basket")

# print("Path to dataset files:", path)

# %%
dataset = pd.read_csv("Market_Basket_Optimisation.csv", header = None)
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %%
transactions = []
for i in range(7501):
    transactions.append([str(dataset.values[i,j]) for j in range(0,20)])
# transactions

# %% [markdown]
# **Wee will use the apriori function from the apyiori module.**
#
# **We need to pass 6 parameters to this funcition.**

# %% [markdown]
# 1. List of the transctions as the main input
# 2. Minimum Support--Let's try to set this to 3 transactions per day. This dataset contains dta collected over a week. Therefore, we will set this value to 3*7/7501=0.00279
# 3. Minimum confidence which we choose to be 0.2
# 4. Minimum Lift: we set this to 3
# 5. Max Length

# %%
from apyori import apriori

# %%
rules = apriori(transactions = transactions, min_support = 0.00279, min_confidence = 0.2, min_lift = 3, max_length = 3)
# max_length = max length of rules
type(rules)
# Out:
# generator

# %%
results = list(rules)
results
print(results)
# Out:
# [RelationRecord(items=frozenset({'extra dark chocolate', 'chicken'}), support=0.0027996267164378083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'chicken'}), confidence=0.23333333333333334, lift=3.8894074074074076)]), RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]), RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]), RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]), RelationRecord(items=frozenset({'fromage blanc', 'honey'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'honey'}), confidence=0.2450980392156863, lift=5.164270764485569)]), RelationRecord(items=frozenset({'herb & pepper', 'ground beef'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)]), RelationRecord(items=frozenset({'tomato sauce', 'ground beef'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'ground beef'}), confidence=0.3773584905660377, lift=3.840659481324083)]), RelationRecord(items=frozenset({'olive oil', 'light cream'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'olive oil'}), confidence=0.20512820512820515, lift=3.1147098515519573)]), RelationRecord(items=frozenset({'whole wheat pasta', 'olive oil'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'olive oil'}), confidence=0.2714932126696833, lift=4.122410097642296)]), RelationRecord(items=frozenset({'shrimp', 'pasta'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'shrimp'}), confidence=0.3220338983050847, lift=4.506672147735896)]), RelationRecord(items=frozenset({'milk', 'spaghetti', 'avocado'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'spaghetti', 'avocado'}), items_add=frozenset({'milk'}), confidence=0.41666666666666663, lift=3.215449245541838)]), RelationRecord(items=frozenset({'cake', 'burgers', 'milk'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake', 'milk'}), items_add=frozenset({'burgers'}), confidence=0.27999999999999997, lift=3.211437308868501)]), RelationRecord(items=frozenset({'burgers', 'turkey', 'chocolate'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'turkey', 'chocolate'}), items_add=frozenset({'burgers'}), confidence=0.27058823529411763, lift=3.1034898363014927)]), RelationRecord(items=frozenset({'burgers', 'turkey', 'milk'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'turkey', 'milk'}), items_add=frozenset({'burgers'}), confidence=0.2823529411764706, lift=3.2384241770102533)]), RelationRecord(items=frozenset({'cake', 'olive oil', 'chocolate'}), support=0.0027996267164378083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake', 'chocolate'}), items_add=frozenset({'olive oil'}), confidence=0.20588235294117646, lift=3.126160990712074)]), Relati ...

# %% [markdown]
# **Seems difficult to understand these assiciate rules like this**

# %%
print(results[2])
# Out:
# RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)])

# %%
print(results[2][2][0][0])
print(type(results[0][2][0][0]))
# Out:
# frozenset({'mushroom cream sauce'})
# <class 'frozenset'>

# %%
def convert(results):
    lhs = [tuple(result[2][0][0]) for result in results]
    rhs = [tuple(result[2][0][1]) for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
    
resultFrame = pd.DataFrame(convert(results), columns=['Left', 'Right', 'Support', 'Confidence', 'Lift'])
resultFrame.head()
# Out:
#                       Left        Right   Support  Confidence      Lift
# 0  (extra dark chocolate,)   (chicken,)  0.002800    0.233333  3.889407
# 1           (light cream,)   (chicken,)  0.004533    0.290598  4.843951
# 2  (mushroom cream sauce,)  (escalope,)  0.005733    0.300699  3.790833
# 3                 (pasta,)  (escalope,)  0.005866    0.372881  4.700812
# 4         (fromage blanc,)     (honey,)  0.003333    0.245098  5.164271

# %%
resultFrame
# Out:
#                              Left          Right   Support  Confidence  \
# 0         (extra dark chocolate,)     (chicken,)  0.002800    0.233333
# 1                  (light cream,)     (chicken,)  0.004533    0.290598
# 2         (mushroom cream sauce,)    (escalope,)  0.005733    0.300699
# 3                        (pasta,)    (escalope,)  0.005866    0.372881
# 4                (fromage blanc,)       (honey,)  0.003333    0.245098
# ..                            ...            ...       ...         ...
# 70                       (pasta,)  (nan, shrimp)  0.005066    0.322034
# 71          (pancakes, spaghetti)   (olive oil,)  0.005066    0.201058
# 72              (soup, spaghetti)   (olive oil,)  0.002933    0.205607
# 73          (tomatoes, olive oil)   (spaghetti,)  0.004399    0.611111
# 74  (whole wheat rice, spaghetti)    (tomatoes,)  0.003066    0.216981
#
#         Lift
# 0   3.889407
# 1   4.843951
# 2   3.790833
# 3   4.700812
# 4   5.164271
# ..       ...
# 70  4.515096
# 71  3.052910
# 72  3.121987
# 73  3.509912
# 74  3.172662
#
# [75 rows x 5 columns]

# %% [markdown]
# **We can sort the final outputs in the descending order of the lift**

# %%
resultFrame.nlargest(n=10, columns='Lift')
# Out:
#                                   Left                     Right   Support  \
# 68  (whole wheat pasta, mineral water)              (olive oil,)  0.003866
# 59                     (tomato sauce,)  (ground beef, spaghetti)  0.003066
# 34                    (fromage blanc,)              (nan, honey)  0.003333
# 52               (ground beef, shrimp)          (herb & pepper,)  0.002933
# 4                     (fromage blanc,)                  (honey,)  0.003333
# 1                       (light cream,)                (chicken,)  0.004533
# 19                      (light cream,)            (nan, chicken)  0.004533
# 37  (frozen vegetables, herb & pepper)            (ground beef,)  0.002800
# 3                             (pasta,)               (escalope,)  0.005866
# 32                            (pasta,)           (escalope, nan)  0.005866
#
#     Confidence      Lift
# 68    0.402778  6.115863
# 59    0.216981  5.535971
# 34    0.245098  5.178818
# 52    0.255814  5.172131
# 4     0.245098  5.164271
# 1     0.290598  4.843951
# 19    0.290598  4.843951
# 37    0.466667  4.749616
# 3     0.372881  4.700812
# 32    0.372881  4.700812

# %% [markdown]
# **In the previous algorithm we could not see the frequent itemsets**

# %% [markdown]
# **Let's look at a different library for this--mlxtend**

# %%
dataset = pd.read_csv('basket_analysis.csv', index_col=0)
dataset
# Out:
#      Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0    False   True   False   False   True   True  False       True
# 1    False  False   False   False  False  False  False      False
# 2     True  False    True   False  False   True  False       True
# 3    False  False    True    True  False   True  False      False
# 4     True   True   False   False  False  False  False      False
# ..     ...    ...     ...     ...    ...    ...    ...        ...
# 994  False   True   False   False  False  False   True      False
# 995   True  False   False   False   True  False  False      False
# 996   True  False   False   False   True   True  False      False
# 997  False  False    True    True   True  False   True       True
# 998  False  False   False   False  False  False  False      False
#
#      Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0           False  False   False  False   True    False    True       True
# 1           False   True   False  False  False    False   False      False
# 2           False   True   False  False  False    False    True       True
# 3           False   True    True   True  False    False   False      False
# 4           False  False   False  False  False    False   False      False
# ..            ...    ...     ...    ...    ...      ...     ...        ...
# 994         False  False   False  False  False     True   False       True
# 995          True   True    True  False  False    False    True      False
# 996         False  False   False  False   True    False   False       True
# 997          True  False    True  False   True    False    True       True
# 998         False   True   False  False  False    False   False       True
#
# [999 rows x 16 columns]

# %% [markdown]
# **Dataset contains 999 transactions. We cannot set minsupport to be too high, as it could result in not realizing interesting patterns.**
#
# **We will set the minsupport to be 0.02**

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.15.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.2.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.6.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\z72w146\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.frequent_patterns import apriori, association_rules
dataset
# Out:
#      Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0    False   True   False   False   True   True  False       True
# 1    False  False   False   False  False  False  False      False
# 2     True  False    True   False  False   True  False       True
# 3    False  False    True    True  False   True  False      False
# 4     True   True   False   False  False  False  False      False
# ..     ...    ...     ...     ...    ...    ...    ...        ...
# 994  False   True   False   False  False  False   True      False
# 995   True  False   False   False   True  False  False      False
# 996   True  False   False   False   True   True  False      False
# 997  False  False    True    True   True  False   True       True
# 998  False  False   False   False  False  False  False      False
#
#      Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0           False  False   False  False   True    False    True       True
# 1           False   True   False  False  False    False   False      False
# 2           False   True   False  False  False    False    True       True
# 3           False   True    True   True  False    False   False      False
# 4           False  False   False  False  False    False   False      False
# ..            ...    ...     ...    ...    ...      ...     ...        ...
# 994         False  False   False  False  False     True   False       True
# 995          True   True    True  False  False    False    True      False
# 996         False  False   False  False   True    False   False       True
# 997          True  False    True  False   True    False    True       True
# 998         False   True   False  False  False    False   False       True
#
# [999 rows x 16 columns]

# %%
frequent_itemsets = apriori(dataset, min_support=0.02, use_colnames=True)

# %%
print(frequent_itemsets)
frequent_itemsets
print(type(frequent_itemsets))
# for i in frequent_itemsets:
#     print(i)
# Out:
#        support                                           itemsets
# 0     0.383383                                            (Apple)
# 1     0.384384                                            (Bread)
# 2     0.420420                                           (Butter)
# 3     0.404404                                           (Cheese)
# 4     0.407407                                             (Corn)
# ...        ...                                                ...
# 5540  0.020020  (Nutmeg, Kidney Beans, Cheese, Ice cream, Dill...
# 5541  0.021021  (chocolate, Kidney Beans, Cheese, Unicorn, Dil...
# 5542  0.020020  (chocolate, Nutmeg, Kidney Beans, Sugar, Chees...
# 5543  0.020020  (chocolate, Corn, Nutmeg, Unicorn, Yogurt, Onion)
# 5544  0.020020  (chocolate, Unicorn, Ice cream, Milk, Dill, On...
#
# [5545 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# **If you want to look at this dataset with the size of the itemset, you can do following:**

# %%
frequent_itemsets['itemset_length'] = frequent_itemsets['itemsets'].apply(len) 
frequent_itemsets
# Out:
#        support                                           itemsets  \
# 0     0.383383                                            (Apple)
# 1     0.384384                                            (Bread)
# 2     0.420420                                           (Butter)
# 3     0.404404                                           (Cheese)
# 4     0.407407                                             (Corn)
# ...        ...                                                ...
# 5540  0.020020  (Nutmeg, Kidney Beans, Cheese, Ice cream, Dill...
# 5541  0.021021  (chocolate, Kidney Beans, Cheese, Unicorn, Dil...
# 5542  0.020020  (chocolate, Nutmeg, Kidney Beans, Sugar, Chees...
# 5543  0.020020  (chocolate, Corn, Nutmeg, Unicorn, Yogurt, Onion)
# 5544  0.020020  (chocolate, Unicorn, Ice cream, Milk, Dill, On...
#
#       itemset_length
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 5540               6
# 5541               6
# 5542               6
# 5543               6
# 5544               6
#
# [5545 rows x 3 columns]

# %% [markdown]
# **If you want to filter this frequent itemset you can do something like this**

# %%
frequent_itemsets[(frequent_itemsets['itemset_length'] == 2 ) & (frequent_itemsets['support']>= 0.2)]
# Out:
#       support                itemsets  itemset_length
# 49   0.207207     (Ice cream, Butter)               2
# 50   0.202202  (Butter, Kidney Beans)               2
# 57   0.202202     (chocolate, Butter)               2
# 62   0.200200  (Cheese, Kidney Beans)               2
# 107  0.202202  (Ice cream, chocolate)               2
# 120  0.211211       (Milk, chocolate)               2

# %% [markdown]
# **If you waant to select entries based on the itemsets you can do the following:**

# %%
frequent_itemsets[(frequent_itemsets['itemsets'] == {'Ice cream', 'chocolate'} ) ]
# Out:
#       support                itemsets  itemset_length
# 107  0.202202  (Ice cream, chocolate)               2

# %%
rules = association_rules(frequent_itemsets, metric="lift", num_itemsets=len(frequent_itemsets), min_threshold=1) 
rules
# Out:
#         antecedents                                   consequents  \
# 0           (Apple)                                       (Bread)
# 1           (Bread)                                       (Apple)
# 2           (Apple)                                      (Butter)
# 3          (Butter)                                       (Apple)
# 4           (Apple)                                      (Cheese)
# ...             ...                                           ...
# 119413    (Unicorn)     (chocolate, Ice cream, Milk, Dill, Onion)
# 119414  (Ice cream)       (chocolate, Unicorn, Milk, Dill, Onion)
# 119415       (Milk)  (chocolate, Unicorn, Ice cream, Dill, Onion)
# 119416       (Dill)  (chocolate, Unicorn, Ice cream, Milk, Onion)
# 119417      (Onion)   (chocolate, Unicorn, Ice cream, Milk, Dill)
#
#         antecedent support  consequent support   support  confidence  \
# 0                 0.383383            0.384384  0.154154    0.402089
# 1                 0.384384            0.383383  0.154154    0.401042
# 2                 0.383383            0.420420  0.188188    0.490862
# 3                 0.420420            0.383383  0.188188    0.447619
# 4                 0.383383            0.404404  0.162162    0.422977
# ...                    ...                 ...       ...         ...
# 119413            0.389389            0.032032  0.020020    0.051414
# 119414            0.410410            0.035035  0.020020    0.048780
# 119415            0.405405            0.031031  0.020020    0.049383
# 119416            0.398398            0.030030  0.020020    0.050251
# 119417            0.403403            0.033033  0.020020    0.049628
#
#             lift  representativity  leverage  conviction  zhangs_metric  \
# 0       1.046059               1.0  0.006788    1.029610       0.071407
# 1       1.046059               1.0  0.006788    1.029482       0.071524
# 2       1.167549               1.0  0.027006    1.138354       0.232730
# 3       1.167549               1.0  0.027006    1.116289       0.247602
# 4       1.045925               1.0  0.007120    1.032186       0.071208
# ...          ...               ...       ...         ...            ...
# 119413  1.605077               1.0  0.007547    1.020432       0.617377
# 119414  1.392334               1.0  0.005641    1.014450       0.477929
# 119415  1.591398               1.0  0.007440    1.019305       0.625000
# 119416  1.673367               1.0  0.008056    1.021291       0.668885
# 119417  1.502369               1.0  0.006694    1.017461       0.560487
#
#          jaccard  certainty  kulczynski
# 0       0.251223   0.028759    0.401565
# 1       0.251223   0.028637    0.401565
# 2       0.305691   0.121538    0.469240
# 3       0.305691   0.104174    0.469240
# 4       0.259200   0.031182    0.411983
# ...          ...        ...         ...
# 119413  0.049875   0.020023    0.338207
# 119414  0.047059   0.014245    0.310105
# 119415  0.048077   0.018939    0.347272
# 119416  0.049020   0.020847    0.358459
# 119417  0.048077   0.017162    0.327844
#
# [119418 rows x 14 columns]

# %%
rules['itemset_size'] = rules['antecedents'].apply(len) + rules['consequents'].apply(len)
# Combine antecedents and consequents into a single string for labels
rules['itemset'] = rules['antecedents'].apply(lambda x: ', '.join(list(x))) + ' -> ' + rules['consequents'].apply(lambda x: ', '.join(list(x)))
rules.sort_values(by="lift", ascending=False).head(10)
# Out:
#                                  antecedents  \
# 118575           (Corn, Sugar, Kidney Beans)
# 118586              (Apple, Cheese, Unicorn)
# 118452               (Unicorn, Bread, Apple)
# 118461                 (Corn, Yogurt, Sugar)
# 119194      (Onion, chocolate, Kidney Beans)
# 119207               (Cheese, Dill, Unicorn)
# 118598                       (Apple, Cheese)
# 118563  (Corn, Sugar, Unicorn, Kidney Beans)
# 118468                        (Bread, Apple)
# 118445        (Corn, Yogurt, Sugar, Unicorn)
#
#                                  consequents  antecedent support  \
# 118575              (Apple, Cheese, Unicorn)            0.090090
# 118586           (Corn, Sugar, Kidney Beans)            0.075075
# 118452                 (Corn, Yogurt, Sugar)            0.076076
# 118461               (Unicorn, Bread, Apple)            0.085085
# 119194               (Cheese, Dill, Unicorn)            0.083083
# 119207      (Onion, chocolate, Kidney Beans)            0.082082
# 118598  (Corn, Sugar, Unicorn, Kidney Beans)            0.162162
# 118563                       (Apple, Cheese)            0.046046
# 118468        (Corn, Yogurt, Sugar, Unicorn)            0.154154
# 118445                        (Bread, Apple)            0.044044
#
#         consequent support   support  confidence      lift  representativity  \
# 118575            0.075075  0.022022    0.244444  3.256000               1.0
# 118586            0.090090  0.022022    0.293333  3.256000               1.0
# 118452            0.085085  0.020020    0.263158  3.092879               1.0
# 118461            0.076076  0.020020    0.235294  3.092879               1.0
# 119194            0.082082  0.021021    0.253012  3.082427               1.0
# 119207            0.083083  0.021021    0.256098  3.082427               1.0
# 118598            0.046046  0.022022    0.135802  2.949275               1.0
# 118563            0.162162  0.022022    0.478261  2.949275               1.0
# 118468            0.044044  0.020020    0.129870  2.948642               1.0
# 118445            0.154154  0.020020    0.454545  2.948642               1.0
#
#         leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 118575  0.015259    1.224165       0.761476  0.153846   0.183117    0.268889
# 118586  0.015259    1.287608       0.749115  0.153846   0.223366    0.268889
# 118452  0.013547    1.241670       0.732394  0.141844   0.194633    0.249226
# 118461  0.013547    1.208208       0.739606  0.141844   0.172328    0.249226
# 119194  0.014201    1.228826       0.736796  0.145833   0.186215    0.254555
# 119207  0.014201    1.232577       0.735992  0.145833   0.188692    0.254555
# 118598  0.014555    1.103861       0.788856  0.118280   0.094089    0.307032
# 118563  0.014555    1.605856       0.692836  0.118280   0.377279    0.307032
# 118468  0.013230    1.098636       0.781302  0.112360   0.089780    0.292208
# 118445  0.013230    1.550717       0.691309  0.112360   0.355137    0.292208
#
#         itemset_size                                            itemset
# 118575             6  Corn, Sugar, Kidney Beans -> Apple, Cheese, Un...
# 118586             6  Apple, Cheese, Unicorn -> Corn, Sugar, Kidney ...
# 118452             6       Unicorn, Bread, Apple -> Corn, Yogurt, Sugar
# 118461             6       Corn, Yogurt, Sugar -> Unicorn, Bread, Apple
# 119194             6  Onion, chocolate, Kidney Beans -> Cheese, Dill...
# 119207             6  Cheese, Dill, Unicorn -> Onion, chocolate, Kid...
# 118598             6  Apple, Cheese -> Corn, Sugar, Unicorn, Kidney ...
# 118563             6  Corn, Sugar, Unicorn, Kidney Beans -> Apple, C...
# 118468             6       Bread, Apple -> Corn, Yogurt, Sugar, Unicorn
# 118445             6       Corn, Yogurt, Sugar, Unicorn -> Bread, Apple

# %% [markdown]
# **We can try to visualize this result as follows**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
scatter = plt.scatter(
    rules['support'],
    rules['lift'],
    c=rules['itemset_size'],
    cmap='viridis',
    alpha=0.8,
    s=50
)


cbar=plt.colorbar(scatter, label='Itemset Size')
# cbar.set_ticks(list(range(2, rules['itemset_size'].max() +1)))

plt.xlabel('Support')
plt.ylabel('Lift')
plt.title('Association Rules: Support vs Lift, Colored by Itemset Size')

plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()  #Adjusts the plot parameters to prevent labels from overlapping or being cut off.

# %% [markdown]
# **Let's do bit of advanced manipulation**

# %%
average_metrics = rules.groupby('itemset_size').agg({'support': 'mean', 'lift':'mean'}).reset_index()
average_metrics
# Out:
#    itemset_size   support      lift
# 0             2  0.183040  1.124878
# 1             3  0.088109  1.194679
# 2             4  0.043649  1.263255
# 3             5  0.023639  1.393657
# 4             6  0.020395  2.139912

# %%
fig, ax1 = plt.subplots(figsize=(12,6))
ax1.plot(average_metrics['itemset_size'], average_metrics['lift'], marker = 'o', color='b', label='Average Lift')
ax1.set_xlabel('Itemset Size')
ax1.set_ylabel('lift', color='b')
# if you want to put some color on the y-axis of the ax1
ax1.tick_params(axis='y', labelcolor='b')

ax2 = ax1.twinx()
ax2.plot(average_metrics['itemset_size'], average_metrics['support'], marker='*', color='r', label='Average Support')
ax2.set_ylabel('Average Support', color='r')
ax2.tick_params(axis='y', labelcolor='r')

plt.title('Average support and Lift by Itemset Size')
fig.tight_layout()

# %% [markdown]
# Support decreases: Larger itemsets (containing more items) are less frequent, as it's rarer for multiple specific items to be purchased together.
#
# Lift increases: Larger itemsets often have higher lift, indicating stronger associations among the items within those sets when they do occur.

# %% [markdown]
# **Now let's see the best set of rules that we have**

# %%
rules_sorted = rules.sort_values(by=['itemset_size', 'lift', 'support'], ascending=[True, False, False])
rules_sorted
# Out:
#                                      antecedents  \
# 206                                       (Milk)
# 207                                  (chocolate)
# 92                                      (Cheese)
# 93                                (Kidney Beans)
# 208                                     (Nutmeg)
# ...                                          ...
# 119288                               (chocolate)
# 119353                                 (Unicorn)
# 119296  (chocolate, Corn, Nutmeg, Yogurt, Onion)
# 119414                               (Ice cream)
# 119359   (chocolate, Unicorn, Milk, Dill, Onion)
#
#                                              consequents  antecedent support  \
# 206                                          (chocolate)            0.405405
# 207                                               (Milk)            0.421421
# 92                                        (Kidney Beans)            0.404404
# 93                                              (Cheese)            0.408408
# 208                                              (Onion)            0.401401
# ...                                                  ...                 ...
# 119288  (Nutmeg, Kidney Beans, Sugar, Cheese, Ice cream)            0.421421
# 119353          (chocolate, Corn, Nutmeg, Yogurt, Onion)            0.389389
# 119296                                         (Unicorn)            0.036036
# 119414           (chocolate, Unicorn, Milk, Dill, Onion)            0.410410
# 119359                                       (Ice cream)            0.035035
#
#         consequent support   support  confidence      lift  representativity  \
# 206               0.421421  0.211211    0.520988  1.236263               1.0
# 207               0.405405  0.211211    0.501188  1.236263               1.0
# 92                0.408408  0.200200    0.495050  1.212143               1.0
# 93                0.404404  0.200200    0.490196  1.212143               1.0
# 208               0.403403  0.195195    0.486284  1.205454               1.0
# ...                    ...       ...         ...       ...               ...
# 119288            0.033033  0.020020    0.047506  1.438134               1.0
# 119353            0.036036  0.020020    0.051414  1.426735               1.0
# 119296            0.389389  0.020020    0.555556  1.426735               1.0
# 119414            0.035035  0.020020    0.048780  1.392334               1.0
# 119359            0.410410  0.020020    0.571429  1.392334               1.0
#
#         leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 206     0.040365    1.207857       0.321413  0.343089   0.172088    0.511088
# 207     0.040365    1.192021       0.330310  0.343089   0.161088    0.511088
# 92      0.035038    1.171583       0.293849  0.326797   0.146454    0.492623
# 93      0.035038    1.168284       0.295838  0.326797   0.144043    0.492623
# 208     0.033269    1.161336       0.284727  0.320197   0.138923    0.485078
# ...          ...         ...            ...       ...        ...         ...
# 119288  0.006099    1.015195       0.526557  0.046083   0.014967    0.326783
# 119353  0.005988    1.016211       0.489836  0.049383   0.015953    0.303485
# 119296  0.005988    1.373874       0.310280  0.049383   0.272131    0.303485
# 119414  0.005641    1.014450       0.477929  0.047059   0.014245    0.310105
# 119359  0.005641    1.375709       0.292012  0.047059   0.273102    0.310105
#
#         itemset_size                                            itemset
# 206                2                                  Milk -> chocolate
# 207                2                                  chocolate -> Milk
# 92                 2                             Cheese -> Kidney Beans
# 93                 2                             Kidney Beans -> Cheese
# 208                2                                    Nutmeg -> Onion
# ...              ...                                                ...
# 119288             6  chocolate -> Nutmeg, Kidney Beans, Sugar, Chee...
# 119353             6  Unicorn -> chocolate, Corn, Nutmeg, Yogurt, Onion
# 119296             6  chocolate, Corn, Nutmeg, Yogurt, Onion -> Unicorn
# 119414             6  Ice cream -> chocolate, Unicorn, Milk, Dill, O...
# 119359             6  chocolate, Unicorn, Milk, Dill, Onion -> Ice c...
#
# [119418 rows x 16 columns]

# %%
top_rules = rules_sorted.groupby('itemset_size').head(1).reset_index(drop=True)
top_rules
# Out:
#                    antecedents               consequents  antecedent support  \
# 0                       (Milk)               (chocolate)            0.405405
# 1               (Cheese, Dill)                   (Onion)            0.177177
# 2               (Cheese, Dill)     (Kidney Beans, Onion)            0.177177
# 3       (Eggs, Apple, Unicorn)             (Corn, Sugar)            0.068068
# 4  (Corn, Sugar, Kidney Beans)  (Apple, Cheese, Unicorn)            0.090090
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.421421  0.211211    0.520988  1.236263               1.0
# 1            0.403403  0.102102    0.576271  1.428523               1.0
# 2            0.170170  0.055055    0.310734  1.826022               1.0
# 3            0.187187  0.030030    0.441176  2.356873               1.0
# 4            0.075075  0.022022    0.244444  3.256000               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 0  0.040365    1.207857       0.321413  0.343089   0.172088    0.511088
# 1  0.030628    1.407968       0.364570  0.213389   0.289757    0.414686
# 2  0.024905    1.203933       0.549768  0.188356   0.169389    0.317132
# 3  0.017289    1.454507       0.617759  0.133333   0.312482    0.300802
# 4  0.015259    1.224165       0.761476  0.153846   0.183117    0.268889
#
#    itemset_size                                            itemset
# 0             2                                  Milk -> chocolate
# 1             3                              Cheese, Dill -> Onion
# 2             4                Cheese, Dill -> Kidney Beans, Onion
# 3             5                Eggs, Apple, Unicorn -> Corn, Sugar
# 4             6  Corn, Sugar, Kidney Beans -> Apple, Cheese, Un...

# %% [markdown]
# **______________________________________________________________________**

# %% [markdown]
# **There is a nice way to create a binary database using mlxtend**

# %%
dataset_market = pd.read_csv("Market_Basket_Optimisation.csv", header = None)
dataset_market.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder() # to transform dataset into binary matrix
# we need to input a list of lists to this encoder
list_of_lists = dataset_market.apply(lambda row: [item for item in row.dropna()], axis=1).tolist()
# print(list_of_lists)

te_transformed = te.fit(list_of_lists).transform(list_of_lists)
df = pd.DataFrame(te_transformed, columns=te.columns_)
df.head()
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False     True               True      False     True        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False    False        False
# 3       False    False              False      False     True        False
# 4       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False            True
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...   False           False
# 3  False           False      False        False  ...    True           False
# 4  False           False      False        False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False              True              False
# 1        False       False             False              False
# 2        False       False             False              False
# 3        False       False             False              False
# 4        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# 0             False   True        False     False
# 1             False  False        False     False
# 2             False  False        False     False
# 3             False  False        False     False
# 4              True  False        False     False
#
# [5 rows x 120 columns]
