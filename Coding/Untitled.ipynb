# %%
import networkx as nx
import numpy as np

# %%
G = nx.Graph()
G.add_edges_from([
(1,2), (1,3), (1,4),
(2,3),
(3,5), (3,12),
(4,5),
(5,11),
(11,12),
(12,7), (12,8), (12,9), (12,10),
(7,6), (8,13), (10,14)
])
nx.draw_networkx(G)

# %%
nx.closeness_centrality(G)
# Out:
# {1: 0.38235294117647056,
#  2: 0.37142857142857144,
#  3: 0.52,
#  4: 0.30952380952380953,
#  5: 0.3939393939393939,
#  12: 0.6190476190476191,
#  11: 0.4482758620689655,
#  7: 0.41935483870967744,
#  8: 0.41935483870967744,
#  9: 0.3939393939393939,
#  10: 0.41935483870967744,
#  6: 0.3023255813953488,
#  13: 0.3023255813953488,
#  14: 0.3023255813953488}

# %%
print(13/19)
# Out:
# 0.6842105263157895

# %%
print(0.6190476190476191/13)
# Out:
# 0.04761904761904762

# %%
i = 12
sum = 0
for j in range(1, 15):
    if i != j:
        print(nx.shortest_path_length(G, 12, j))
        sum += nx.shortest_path_length(G, 12, j)
print(sum)
# Out:
# 2
# 2
# 1
# 3
# 2
# 2
# 1
# 1
# 1
# 1
# 1
# 2
# 2
# 21
