# %%
import networkx as nx
from networkx import grid_graph
G = grid_graph(dim=(2, 2))
len(G)
# Out:
# 4

# %%
nx.draw(G, with_labels=True, font_color="white")

# %%
print(G.nodes())
# Out:
# [(0, 0), (0, 1), (1, 0), (1, 1)]

# %%
for i in G.nodes():
    print(f'i: {i} type: {type(i)}')
# Out:
# i: (0, 0) type: <class 'tuple'>
# i: (0, 1) type: <class 'tuple'>
# i: (1, 0) type: <class 'tuple'>
# i: (1, 1) type: <class 'tuple'>

# %%
G.nodes
# Out:
# NodeView(((0, 0), (0, 1), (1, 0), (1, 1)))

# %%
G.nodes[(0,0)]
# Out:
# {}

# %%
if (
